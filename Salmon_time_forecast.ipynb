# %% [markdown]
# # Salmon Price Time Series Forecasting

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
import seaborn as sns
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Data Preparation and Exploration

# %%
df = pd.read_html('fish-data.html')
df = df[0]
df
# Out:
#         Month  Price  Change
# 0    May 1994   5.43       -
# 1    Jun 1994   5.46   0.55%
# 2    Jul 1994   5.24  -4.03%
# 3    Aug 1994   5.02  -4.20%
# 4    Sep 1994   5.28   5.18%
# ..        ...    ...     ...
# 355  Dec 2023   8.28   9.96%
# 356  Jan 2024  10.21  23.31%
# 357  Feb 2024  10.27   0.59%
# 358  Mar 2024  10.16  -1.07%
# 359  Apr 2024  10.96   7.87%
#
# [360 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 360 entries, 0 to 359
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Month   360 non-null    object
#  1   Price   360 non-null    float64
#  2   Change  360 non-null    object
# dtypes: float64(1), object(2)
# memory usage: 8.6+ KB

# %% [markdown]
# data has 360 entries with no missing data entries. The next steps are parsing the Month to become a Date column and to parse the Change column into decimal form

# %%
df.shape
# Out:
# (360, 3)

# %%
df.describe()
# Out:
#             Price
# count  360.000000
# mean     5.363833
# std      1.857991
# min      2.400000
# 25%      3.860000
# 50%      5.025000
# 75%      6.690000
# max     11.250000

# %% [markdown]
# At first glance, the variance of salmon price is around 5 dollars with a standard deviation of around 2 dollars.

# %%
df.columns
# Out:
# Index(['Month', 'Price', 'Change'], dtype='object')

# %%
df.rename(columns= {'Month': 'Date'}, inplace= True)
df.head()
# Out:
#        Date  Price  Change
# 0  May 1994   5.43       -
# 1  Jun 1994   5.46   0.55%
# 2  Jul 1994   5.24  -4.03%
# 3  Aug 1994   5.02  -4.20%
# 4  Sep 1994   5.28   5.18%

# %%
#convert to datetime format
df['Date'] = pd.to_datetime(df['Date'])
df.head()
# Out:
#         Date  Price  Change
# 0 1994-05-01   5.43       -
# 1 1994-06-01   5.46   0.55%
# 2 1994-07-01   5.24  -4.03%
# 3 1994-08-01   5.02  -4.20%
# 4 1994-09-01   5.28   5.18%

# %%
#parse Change column to usable format

df['Change'] = df['Change'][1:].apply(lambda x: x[0:-1]).astype(float)
df['Change'] = df['Change'] / 100
df = df[['Date', 'Change', 'Price']]
df.rename(columns= {'Change': 'Change in decimal'}, inplace= True)

df.head()
# Out:
#         Date  Change in decimal  Price
# 0 1994-05-01                NaN   5.43
# 1 1994-06-01             0.0055   5.46
# 2 1994-07-01            -0.0403   5.24
# 3 1994-08-01            -0.0420   5.02
# 4 1994-09-01             0.0518   5.28

# %%
df.dtypes
# Out:
# Date                 datetime64[ns]
# Change in decimal           float64
# Price                       float64
# dtype: object

# %% [markdown]
# We have converted given featues to correct datatypes for more exploratory use

# %% [markdown]
# ## Data Exploration

# %%
plt.figure(figsize = (30,10))
plt.subplot(1,3,1)
plt.title('Salmon Price over Time')
plt.xlabel('Time')
plt.ylabel('Salmon Price')
plt.plot(df['Date'], df['Price'], color= 'r')
plt.grid(True)

plt.subplot(1,3,2)
plt.title('Salmon Price over Price Change in decimal per Month')
plt.xlabel('Change')
plt.ylabel('Price')
plt.scatter(df['Change in decimal'], df['Price'], alpha= .6)
plt.grid(True)

plt.subplot(1,3,3)
plt.title('Price Change in decimal per Month over Time')
plt.xlabel('Time')
plt.ylabel('Price Change')
plt.plot(df['Date'], df['Change in decimal'], color= 'g')
plt.grid(True)

plt.show()

# %% [markdown]
# These 3 plots aim to explore the relationship between dependent variables and also our target variable, price. Salmon price over time seems to follow a seasonal trend that is represented by its many jagged valleys and peaks. Initially salmon price trends downwards until around 2004, where a seasonal and linear trend occurs until 2024. From around 2020-2024 the price seems to be extremely volatile with high peaks and low valleys. There seems to be little to no correlation when we look at the relationship between price change per month in decimal form and price, this similarly follows for price change per month over date time. Let us isolate a time period to see more closely how the seasonality of salmon pricing works.

# %%
dates_of_2022 = df[(df['Date'] >= '2022-01-01') & (df['Date'] < '2023-01-01')]['Date']
prices_of_2022 = df[(df['Date'] >= '2022-01-01') & (df['Date'] < '2023-01-01')]['Price']
labels = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

x = [2*np.pi*i/12 for i in range(0,12)]
theory = [2*np.sin(i) + 8 for i in x]

plt.figure(figsize= (8,8))
plt.subplot(3,1,1)
plt.title('Salmon Price over Year 2022')
plt.plot(dates_of_2022, prices_of_2022, label= 'actual')
plt.scatter(dates_of_2022, prices_of_2022, color= 'm', label='points')
plt.xticks(ticks= dates_of_2022, labels= [])
plt.grid(True)
plt.legend()
plt.tight_layout()

plt.subplot(3,1,2)
plt.plot(x, theory, color= 'red', label= 'theory')
plt.xticks(ticks= x, labels= [])
plt.grid(True)
plt.legend()
plt.ylabel('Price (USD)')


plt.subplot(3,1,3)
plt.plot(dates_of_2022, prices_of_2022, color= 'blue', label= 'actual')
plt.plot(dates_of_2022, theory, color= 'red', label= 'theory')
plt.scatter(dates_of_2022, prices_of_2022, color= 'm', label= 'points')
plt.xticks(ticks= dates_of_2022, labels= labels)
plt.xlabel('Year 2022 (Months)')
plt.grid(True)
plt.legend()
plt.tight_layout()

plt.show()

# %% [markdown]
# Salmon Price throughout the year in 2022 seems to follow a sinusoidal pattern, where at the beginning of the year it follows a steay linear trend to around 10.50 in May before following a downwards trend to September where the price of the fish is at a minimum of 6.00 for the year before returing back to around the starting price of the year, around 8 dollars. The price changes throughout the year can indicate salmon migration patterns in Norway because the drop in price for the summer period can indicate that Salmon are ready to spawn and head up stream which causes an influx of Salmon in the area causing prices to lower. In seasons like the winter, where salmon is not in season, we can expect an upwards trend in price before climaxing right, when the salmon season starts. This understanding of seasonality offers new features and helps us understand the pricing of salmon much better.

# %% [markdown]
# ## Feature Engineering

# %%
import datetime as dt

# %%
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month
df['Quarter'] = df['Date'].dt.quarter
df['Month_sin'] = np.sin(2*np.pi*df['Month']/12) # to model seasonal patterns
df['Month_cos'] = np.cos(2*np.pi*df['Month']/12) # to model seasonal patterns
df['lag_1'] = df['Price'].shift(1) # previous month price
df['lag_2'] = df['Price'].shift(2) # previpous 2 months ago price
df['lag_3'] = df['Price'].shift(3) # previous 3 months ago price
df['rolling_avg_3'] = df['Price'].rolling(window= 3).mean() # average of past 3 months price
df.head()
# Out:
#         Date  Change in decimal  Price  Year  Month  Quarter     Month_sin  \
# 0 1994-05-01                NaN   5.43  1994      5        2  5.000000e-01
# 1 1994-06-01             0.0055   5.46  1994      6        2  1.224647e-16
# 2 1994-07-01            -0.0403   5.24  1994      7        3 -5.000000e-01
# 3 1994-08-01            -0.0420   5.02  1994      8        3 -8.660254e-01
# 4 1994-09-01             0.0518   5.28  1994      9        3 -1.000000e+00
#
#       Month_cos  lag_1  lag_2  lag_3  rolling_avg_3
# 0 -8.660254e-01    NaN    NaN    NaN            NaN
# 1 -1.000000e+00   5.43    NaN    NaN            NaN
# 2 -8.660254e-01   5.46   5.43    NaN       5.376667
# 3 -5.000000e-01   5.24   5.46   5.43       5.240000
# 4 -1.836970e-16   5.02   5.24   5.46       5.180000

# %%
columns_ordered = [
                    'Date', 'Year', 'Quarter', 'Month',
                    'Month_sin', 'Month_cos', 'Change in decimal',
                    'lag_1', 'lag_2','lag_3','rolling_avg_3',
                    'Price'
                    ]
df = df[columns_ordered]
fig, ax = plt.subplots(figsize= (10,8))
ax.set_title('Heat Map')
sns.heatmap(df.corr(), annot= True, fmt = '.2f', ax=ax, center= -.3)
plt.show()

# %% [markdown]
# This correlation plot explains the relationships between all variables. The price variable is strongly correlated to all the lag features as well as the year feature. there is also low correlation between the sinusoidal month transformation and change in decimal transformation. Knowing these relationships will be useful for what key features we want to feed our model, however, it will still be useful to keep some of these low correlated features as this plot tells us which features that are strongly linearly correlated, some features may have non-linear relationships that will be able to be found and used by some more complex models.

# %% [markdown]
# ## Simple Linear Regression

# %% [markdown]
# ### Model Training

# %%
#imports
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
num_samples = len(df)
test_size = num_samples*.2
split_point = num_samples - int(test_size)

X_train = df['Year'][:split_point]
X_test = df['Year'][split_point:]
y_train = df['Price'][:split_point]
y_test = df['Price'][split_point:]

# %% [markdown]
# Since we are dealing with time series data, the order of the data matters, so we will select the first 80% of examples to be our training set and the remaining 20% of the data to be our test set that we want to forecast on.

# %%
X_train.shape #verifying shape is correct
# Out:
# (288,)

# %%
X_train, X_test = X_train.values.reshape(-1,1), X_test.values.reshape(-1,1)

# %% [markdown]
# Here we transform the training and testing sets to be arrays rather than pandas series' so we can use it in our model

# %%
reg = LinearRegression()
reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### Model Exploration and Evaluation

# %%
reg.coef_, reg.intercept_
# Out:
# (array([0.1493316]), -294.72965269763415)

# %%
def regression_line(a, b, data):
    return a*data + b

reg_line = regression_line(reg.coef_[0], reg.intercept_, df['Year'])

# %%
plt.figure(figsize= (10,6))
plt.title('Simple Linear Regression')
plt.xlabel('Time (Years)')
plt.ylabel('Price')
plt.plot(df['Date'][split_point:], df['Price'][split_point:], label= 'Test Data', color= 'blue')
plt.plot(df['Date'][:split_point], df['Price'][:split_point], label= 'Train Data', color= 'red')
plt.plot(df['Date'], reg_line, label= 'Regression Line', color= 'green')
plt.legend()
plt.grid(True)
plt.tight_layout()

plt.show()

# %% [markdown]
# The plot aims shows how our regression line fits against the training data as well as the testing data. The regression line similar to a step function because we had to fix the month in order to plot against date time, in turn losing some dimensionality. As expected, the simple linear regression does not capture much of the variance or seasonal trends within the data, it simply captures the trivial positive linear trend of salmon price against time. Let us evaluate this model to see how it truly performs.

# %% [markdown]
# We will be using the evaluation metrics root mean squared error in a combination with R2 scoring. Root mean squred error is a useful metric because it will be in the same units as our target variable and will explain how close our model is to the actual ouput. R2 score is useful because it explains how our models independent features are able to capture the variance of the target variable, pricing. Now that we have selected our evaluation metrics we are able to proceed. The loss function that will be selected will be mean squared error (mse). This is a common loss function in regression is used for the machine learning models and neural networks.

# %%
y_pred = reg.predict(X_test)
print(f'Root Mean Squared Error: {np.sqrt(mean_squared_error(y_test, y_pred))}')
print(f'R^{2} Score: {r2_score(y_test, y_pred)}')
# Out:
# Root Mean Squared Error: 1.5165672020572674
# R^2 Score: 0.04493412593097201

# %% [markdown]
# simple linear regression gives us an rmse of 1.52 and an R2 score of .04. This means that on average, the forecasted data is around 1.52 dollars off the expected data. The R2 score means that the model does not explain the variance of the data well. These numbers suggest that the model is underfitting the data and we need a more complex model to capture these trends

# %% [markdown]
# ## Multivariate Polynomial Regression

# %% [markdown]
# ### Model Prepping/Training

# %% [markdown]
# Since we need a more complex model and more features, since the simple regression underfit the data, let us turn to polynomial regression with multiple variables. We will be using our cyclic representation of month, as well as the time related features that were strongly correlated with our target variable from our correlation plot.

# %%
X_train = df[['Year', 'Month_sin', 'Month_cos','lag_1', 'lag_2','lag_3', 'rolling_avg_3']][:split_point].dropna()
X_test = df[['Year', 'Month_sin', 'Month_cos','lag_1', 'lag_2','lag_3', 'rolling_avg_3']][split_point+3:]
y_train = df['Price'][3:split_point]
y_test = df['Price'][split_point+3:]

# %% [markdown]
# X_train drops its first three rows due to null values, so we correct y_train accordingly. Similarly, for X_test, in order to prevent data leakage, we increment the starting position for the testing set by 3, so our lags and rolling averages do not account for any data from the training set. We correct y_test accorindly.

# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree= 2) #plot of date vs price shows a exponential/quadratic curve, so we use degree of 2

X_train_poly = poly.fit_transform(X_train)
X_test_poly = poly.transform(X_test)

# %% [markdown]
# Polynomial regression is an extension of linear regression so we use this idea to transform our X_train/X_test so we can feed it into a linear regression model and then plot the results

# %%
reg = LinearRegression()
reg.fit(X_train_poly, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### Model Evaluation

# %%
X_train_graph = df['Date'][3:split_point]
X_test_graph = df['Date'][split_point+3:]
y_pred = reg.predict(X_test_poly)

plt.subplots(2,1, figsize= (9,6))
plt.subplot(2,1,1)
plt.title('Price over Time')
plt.plot(X_train_graph, y_train, label= 'Train Data', color= 'blue',alpha= .7)
plt.plot(X_test_graph, y_test, label= 'Test Data', color= 'red',alpha= .7)
plt.plot(X_test_graph, y_pred, label= 'Predicted', color= 'green')
plt.ylabel('Price')
plt.xlabel('Years')
plt.grid()
plt.legend()
plt.tight_layout()

plt.subplot(2,1,2)
plt.title('Price over Time')
plt.plot(X_test_graph, y_test, label= 'Test Data', color= 'red',alpha= .7)
plt.plot(X_test_graph, y_pred, label= 'Predicted', color= 'green')
plt.ylabel('Price')
plt.xlabel('Years')
plt.grid()
plt.legend()
plt.tight_layout()

plt.show()

# %%
y_pred = reg.predict(X_test_poly)
print(f'Root Mean Squared Error: {np.sqrt(mean_squared_error(y_test, y_pred))}')
print(f'R^{2} score: {r2_score(y_test, y_pred)}')
# Out:
# Root Mean Squared Error: 6.859858936483364e-13
# R^2 score: 1.0

# %% [markdown]
# An R2 score of 1 and RMSE of 0 means that the model perfectly captures the variance of our target variable, however, this does not make sense. This score is way too good and this means that the model is either overfitting the data or there is a data leakage. There most likely is not a data leakage because of the way the training and test splits are set up, so it means that the model must somehow be overfitting the data, which I still question heavily. In order to test this, i will train the model with randomized test targets. If the R2 score is poor for this randomized training, then the model is not overfitting.

# %%
y_train_random = np.random.permutation(y_train)

reg.fit(X_train_poly, y_train_random)

y_pred_random = reg.predict(X_test_poly)

print(f"Root Mean Squared Error on randomized data: {np.sqrt(mean_squared_error(y_test, y_pred_random))}")
print(f"R^2 score on randomized data: {r2_score(y_test, y_pred_random)}")
# Out:
# Root Mean Squared Error on randomized data: 3.9918725443634315
# R^2 score on randomized data: -5.431980039553335

# %% [markdown]
# The R2 score is terrible and so is the rmse. This means that the model is not overfitting on the data. This leaves me conlcuding that the model is not overfitting the data and there is not a data leakage, so the feature engineering must reveal great predictive power in addition to the ability of polynomial regression being able to capture such complex trends. However, I am still skeptical and as a result will continue to test more models.

# %% [markdown]
# ## Gradient Boosting, Random Forest, KNN, and Gaussian Process

# %%
from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.preprocessing import MinMaxScaler

#scale data to enhance model performance
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

models = {
          'Gradient Boosting Regression': GradientBoostingRegressor(),
          'Random Forest Regression': RandomForestRegressor(),
          'KNearestNeighbors Regression': KNeighborsRegressor(),
          'Gaussian Regression': GaussianProcessRegressor()
         }

# %% [markdown]
# ### Cross Validation Testing

# %%
from sklearn.model_selection import KFold, cross_validate
skf = KFold(n_splits= 5, shuffle= True, random_state= 42)
scoring = {'rmse': 'neg_root_mean_squared_error', 'r2': 'r2'}

for name, model in models.items():
    scores = cross_validate(model, X_train_scaled, y_train, cv= skf, scoring= scoring)
    print('Model Name: ', name)
    print('Average MSE: ', -1*scores['test_rmse'].mean())
    print('Average R^2: ', scores['test_r2'].mean(), '\n')
# Out:
# Model Name:  Gradient Boosting Regression
# Average MSE:  0.26784040929145475
# Average R^2:  0.9660456439600462
#
# Model Name:  Random Forest Regression
# Average MSE:  0.27132082678712266
# Average R^2:  0.9649462472229319
#
# Model Name:  KNearestNeighbors Regression
# Average MSE:  0.41347691273525466
# Average R^2:  0.9191992472711412
#
# Model Name:  Gaussian Regression
# Average MSE:  0.00604210878803333
# Average R^2:  0.9999828129165473

# %% [markdown]
# All the models seem to perform extemely well on the cross validation data sets, with the best being Gaussian Process regression and the worst being KNN regression.

# %% [markdown]
# ### Model Evaluation

# %%
for name, model in models.items():
    model.fit(X_train_scaled, y_train)
    y_pred = model.predict(X_test_scaled)
    print('Model Name: ', name)
    print('RMSE: ', np.sqrt(mean_squared_error(y_test, y_pred)))
    print('R^2: ', model.score(X_test, y_test), '\n')
# Out:
# Model Name:  Gradient Boosting Regression
# RMSE:  1.0300564740749911
# R^2:  -0.036307063487707625
#
# Model Name:  Random Forest Regression
# RMSE:  1.0838134469668141
# R^2:  -0.030164759582025802
#
# Model Name:  KNearestNeighbors Regression
# RMSE:  1.2114553710071325
# R^2:  -0.04290985317027718
#
# Model Name:  Gaussian Regression
# RMSE:  0.44829808548008665
# R^2:  -23.22259903426139

# %% [markdown]
# On unseen data, the previously best model, gaussian regression performs extremely poorly with such a low R2 score. all the models have negative R2 scores that are close to 0 indicating that the models predictions are less accurate than simply predicting the mean value of the target. However, the rmse scores for the models perform well, so feature engineering is not the issue at hand. I suspect that high volatility of salmon pricing, especially as we previously saw in the graph from polynomial regression. With this being said, the best model to forecast is gradient boosting.

# %%
predictions = {}
for name, model in models.items():
    predictions[name] = model.predict(X_test_scaled)

Y = {}
for name, model in models.items():
    Y[name] = [None]*len(df[:split_point]) + predictions[name].tolist()


X_test_graph = df['Date'][split_point+3:]
y_test_graph = df['Price'][split_point+3:]


plt.subplots(2,1, figsize= (10, 8))
plt.subplot(2,1,1)
plt.title('Gradient Boosting')
plt.ylabel('Price')
plt.xlabel('Year')
plt.plot(df['Date'], df['Price'], label= 'Actual', alpha= .8)
plt.plot(df['Date'][3:], Y['Gradient Boosting Regression'], label= 'Predicted', color= 'orange')
plt.legend()
plt.grid()
plt.tight_layout()

plt.subplot(2,1,2)
plt.title('Gradient Boosting (Zoomed)')
plt.ylabel('Price')
plt.xlabel('Year')
plt.plot(X_test_graph, y_test_graph, label= 'Actual', alpha= .8)
plt.plot(X_test_graph , predictions['Gradient Boosting Regression'], label= 'Predicted', color= 'orange')
plt.legend()
plt.grid()
plt.tight_layout()

plt.show()

# %%
plt.subplots(2,1, figsize= (10,8))
plt.subplot(2,1,1)
plt.title('Random Forest')
plt.ylabel('Price')
plt.xlabel('Year')
plt.plot(df['Date'], df['Price'], label= 'Actual', alpha= .8)
plt.plot(df['Date'][3:], Y['Random Forest Regression'], label= 'Predicted', color= 'green')
plt.legend()
plt.grid()
plt.tight_layout()

plt.subplot(2,1,2)
plt.title('Random Forest (Zoomed)')
plt.ylabel('Price')
plt.xlabel('Year')
plt.plot(X_test_graph, y_test_graph, label= 'Actual', alpha= .8)
plt.plot(X_test_graph, predictions['Random Forest Regression'], label= 'Predicted', color= 'green')
plt.legend()
plt.grid()
plt.tight_layout()

plt.show()

# %%
plt.subplots(2,1, figsize= (10,8))
plt.subplot(2,1,1)
plt.title('KNearestNeighbors (k=5)')
plt.ylabel('Price')
plt.xlabel('Year')
plt.plot(df['Date'], df['Price'], label= 'Actual', alpha= .8)
plt.plot(df['Date'][3:], Y['KNearestNeighbors Regression'], label= 'Predicted', color= 'red')
plt.legend()
plt.grid()
plt.tight_layout()

plt.subplot(2,1,2)
plt.title('KNearestNeighbors (k=5) (Zoomed)')
plt.ylabel('Price')
plt.xlabel('Year')
plt.plot(X_test_graph, y_test_graph, label= 'Actual', alpha= .8)
plt.plot(X_test_graph, predictions['KNearestNeighbors Regression'], label= 'Predicted', color= 'red')
plt.legend()
plt.grid()
plt.tight_layout()

plt.show()

# %% [markdown]
# For all 3 plots, the general trend of the predicted plot seems to be nearly identical with these models being able to closely predict the actual price values from years 2019-2022, however, after 2022 there is more volatility in price and the models are not able to effectively capture this trend. Solutions to this would be to hyperparameter tune these models to account for this or have more robust feature engineering.

# %% [markdown]
# ## Neural Networks

# %%
import tensorflow as tf
import keras
from keras import layers
from keras import metrics

# %% [markdown]
# ## Model Architecture

# %%
model = keras.Sequential(
    [
        layers.Dense(32, activation= 'relu', name= 'layer1', input_shape= [7]),
        layers.Dense(12, activation= 'relu', name= 'layer2'),
        layers.Dense(1, activation= 'relu' ,name= 'outputlayer')
    ]
)

# %%
model.compile(
    optimizer= 'sgd',
    loss= 'mse',
    metrics= [metrics.RootMeanSquaredError() ,metrics.R2Score()]
)

# %% [markdown]
# ## Model Training

# %%
history = model.fit(X_train_scaled, y_train, epochs= 150)
# Out:
# Epoch 1/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 21.0169 - r2_score: -8.3361 - root_mean_squared_error: 4.5449
# Epoch 2/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9144 - r2_score: 0.5775 - root_mean_squared_error: 0.9434
# Epoch 3/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3855 - r2_score: 0.8349 - root_mean_squared_error: 0.6201
# Epoch 4/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3062 - r2_score: 0.8603 - root_mean_squared_error: 0.5526
# Epoch 5/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2587 - r2_score: 0.8726 - root_mean_squared_error: 0.5081
# Epoch 6/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2333 - r2_score: 0.8904 - root_mean_squared_error: 0.4830
# Epoch 7/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2242 - r2_score: 0.8916 - root_mean_squared_error: 0.4733
# Epoch 8/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2030 - r2_score: 0.9090 - root_mean_squared_error: 0.4504
# Epoch 9/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2058 - r2_score: 0.8995 - root_mean_squared_error: 0.4534
# Epoch 10/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1720 - r2_score: 0.9203 - root_mean_squared_error: 0.4145
# Epoch 11/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1961 - r2_score: 0.9075 - root_mean_squared_error: 0.4406
# Epoch 12/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1896 - r2_score: 0.9185 - root_mean_squared_error: 0.4351
# Epoch 13/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1425 - r2_score: 0.9346 - root_mean_squared_error: 0.3755
# Epoch 14/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1562 - r2_score: 0.9285 - root_mean_squared_error: 0.3950
# Epoch 15/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1419 - r2_score: 0.9323 - root_mean_squared_error: 0.3752
# Epoch 16/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1514 - r2_score: 0.9271 - root_mean_squared_error: 0.3888
# Epoch 17/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1721 - r2_score: 0.9209 - root_mean_squared_error: 0.4146
# Epoch 18/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1576 - r2_score: 0.9274 - root_mean_squared_error: 0.3968
# Epoch 19/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1599 - r2_score: 0.9231 - root_mean_squared_error: 0.3996
# Epoch 20/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1566 - r2_score: 0.9245 - root_mean_squared_error: 0.3952
# Epoch 21/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1653 - r2_score: 0.9148 - root_mean_squared_error: 0.4063
# Epoch 22/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1321 - r2_score: 0.9406 - root_mean_squared_error: 0.3632
# Epoch 23/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1728 - r2_score: 0.9212 - root_mean_squared_error: 0.4146
# Epoch 24/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1517 - r2_score: 0.9313 - root_mean_squared_error: 0.3892
# Epoch 25/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1498 - r2_score: 0.9358 - root_mean_squared_error: 0.3866
# Epoch 26/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1454 - r2_score: 0.9371 - root_mean_squared_error: 0.3812
# Epoch 27/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1306 - r2_score: 0.9418 - root_mean_squared_error: 0.3607
# Epoch 28/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1661 - r2_score: 0.9271 - root_mean_squared_error: 0.4050
# Epoch 29/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1405 - r2_score: 0.9345 - root_mean_squared_error: 0.3744
# Epoch 30/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1337 - r2_score: 0.9379 - root_mean_squared_error: 0.3655
# Epoch 31/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1472 - r2_score: 0.9313 - root_mean_squared_error: 0.3833
# Epoch 32/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1400 - r2_score: 0.9392 - root_mean_squared_error: 0.3737
# Epoch 33/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1107 - r2_score: 0.9424 - root_mean_squared_error: 0.3316
# Epoch 34/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1285 - r2_score: 0.9327 - root_mean_squared_error: 0.3584
# Epoch 35/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1358 - r2_score: 0.9269 - root_mean_squared_error: 0.3684
# Epoch 36/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1202 - r2_score: 0.9429 - root_mean_squared_error: 0.3463
# Epoch 37/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1529 - r2_score: 0.9271 - root_mean_squared_error: 0.3903
# Epoch 38/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1199 - r2_score: 0.9460 - root_mean_squared_error: 0.3448
# Epoch 39/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1247 - r2_score: 0.9390 - root_mean_squared_error: 0.3527
# Epoch 40/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1216 - r2_score: 0.9449 - root_mean_squared_error: 0.3486
# Epoch 41/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1392 - r2_score: 0.9350 - root_mean_squared_error: 0.3728
# Epoch 42/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1219 - r2_score: 0.9426 - root_mean_squared_error: 0.3488
# Epoch 43/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1255 - r2_score: 0.9394 - root_mean_squared_error: 0.3541
# Epoch 44/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1305 - r2_score: 0.9342 - root_mean_squared_error: 0.3612
# Epoch 45/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1405 - r2_score: 0.9397 - root_mean_squared_error: 0.3746
# Epoch 46/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1205 - r2_score: 0.9400 - root_mean_squared_error: 0.3465
# Epoch 47/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1296 - r2_score: 0.9382 - root_mean_squared_error: 0.3594
# Epoch 48/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1271 - r2_score: 0.9428 - root_mean_squared_error: 0.3564
# Epoch 49/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1311 - r2_score: 0.9353 - root_mean_squared_error: 0.3615
# Epoch 50/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1202 - r2_score: 0.9471 - root_mean_squared_error: 0.3463
# Epoch 51/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1383 - r2_score: 0.9361 - root_mean_squared_error: 0.3716
# Epoch 52/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1135 - r2_score: 0.9389 - root_mean_squared_error: 0.3365
# Epoch 53/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1236 - r2_score: 0.9394 - root_mean_squared_error: 0.3511
# Epoch 54/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1080 - r2_score: 0.9511 - root_mean_squared_error: 0.3278
# Epoch 55/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1230 - r2_score: 0.9475 - root_mean_squared_error: 0.3504
# Epoch 56/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1184 - r2_score: 0.9382 - root_mean_squared_error: 0.3437
# Epoch 57/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1370 - r2_score: 0.9368 - root_mean_squared_error: 0.3696
# Epoch 58/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1223 - r2_score: 0.9461 - root_mean_squared_error: 0.3493
# Epoch 59/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1077 - r2_score: 0.9526 - root_mean_squared_error: 0.3275
# Epoch 60/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1301 - r2_score: 0.9426 - root_mean_squared_error: 0.3600
# Epoch 61/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1172 - r2_score: 0.9433 - root_mean_squared_error: 0.3416
# Epoch 62/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1168 - r2_score: 0.9428 - root_mean_squared_error: 0.3418
# Epoch 63/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1142 - r2_score: 0.9463 - root_mean_squared_error: 0.3379
# Epoch 64/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1152 - r2_score: 0.9440 - root_mean_squared_error: 0.3384
# Epoch 65/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1188 - r2_score: 0.9478 - root_mean_squared_error: 0.3442
# Epoch 66/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1111 - r2_score: 0.9489 - root_mean_squared_error: 0.3320
# Epoch 67/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1269 - r2_score: 0.9455 - root_mean_squared_error: 0.3560
# Epoch 68/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1179 - r2_score: 0.9511 - root_mean_squared_error: 0.3430
# Epoch 69/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1285 - r2_score: 0.9371 - root_mean_squared_error: 0.3578
# Epoch 70/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1337 - r2_score: 0.9423 - root_mean_squared_error: 0.3648
# Epoch 71/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1171 - r2_score: 0.9444 - root_mean_squared_error: 0.3420
# Epoch 72/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1021 - r2_score: 0.9507 - root_mean_squared_error: 0.3190
# Epoch 73/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1059 - r2_score: 0.9496 - root_mean_squared_error: 0.3248
# Epoch 74/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1316 - r2_score: 0.9413 - root_mean_squared_error: 0.3620
# Epoch 75/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1176 - r2_score: 0.9466 - root_mean_squared_error: 0.3426
# Epoch 76/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1220 - r2_score: 0.9463 - root_mean_squared_error: 0.3491
# Epoch 77/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1092 - r2_score: 0.9459 - root_mean_squared_error: 0.3303
# Epoch 78/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1175 - r2_score: 0.9484 - root_mean_squared_error: 0.3425
# Epoch 79/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1062 - r2_score: 0.9479 - root_mean_squared_error: 0.3258
# Epoch 80/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1019 - r2_score: 0.9505 - root_mean_squared_error: 0.3180
# Epoch 81/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1105 - r2_score: 0.9495 - root_mean_squared_error: 0.3324
# Epoch 82/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1001 - r2_score: 0.9518 - root_mean_squared_error: 0.3160
# Epoch 83/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1096 - r2_score: 0.9526 - root_mean_squared_error: 0.3309
# Epoch 84/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1074 - r2_score: 0.9491 - root_mean_squared_error: 0.3275
# Epoch 85/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1009 - r2_score: 0.9542 - root_mean_squared_error: 0.3170
# Epoch 86/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1252 - r2_score: 0.9468 - root_mean_squared_error: 0.3532
# Epoch 87/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1139 - r2_score: 0.9477 - root_mean_squared_error: 0.3371
# Epoch 88/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1031 - r2_score: 0.9542 - root_mean_squared_error: 0.3205
# Epoch 89/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1093 - r2_score: 0.9508 - root_mean_squared_error: 0.3303
# Epoch 90/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1082 - r2_score: 0.9491 - root_mean_squared_error: 0.3285
# Epoch 91/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1043 - r2_score: 0.9548 - root_mean_squared_error: 0.3228
# Epoch 92/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0965 - r2_score: 0.9518 - root_mean_squared_error: 0.3100
# Epoch 93/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0949 - r2_score: 0.9533 - root_mean_squared_error: 0.3068
# Epoch 94/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0947 - r2_score: 0.9551 - root_mean_squared_error: 0.3073
# Epoch 95/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1231 - r2_score: 0.9471 - root_mean_squared_error: 0.3502
# Epoch 96/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1176 - r2_score: 0.9459 - root_mean_squared_error: 0.3421
# Epoch 97/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1080 - r2_score: 0.9469 - root_mean_squared_error: 0.3280
# Epoch 98/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1025 - r2_score: 0.9521 - root_mean_squared_error: 0.3197
# Epoch 99/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1067 - r2_score: 0.9451 - root_mean_squared_error: 0.3266
# Epoch 100/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0946 - r2_score: 0.9528 - root_mean_squared_error: 0.3070
# Epoch 101/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0981 - r2_score: 0.9522 - root_mean_squared_error: 0.3126
# Epoch 102/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1045 - r2_score: 0.9499 - root_mean_squared_error: 0.3228
# Epoch 103/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0958 - r2_score: 0.9575 - root_mean_squared_error: 0.3092
# Epoch 104/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1077 - r2_score: 0.9511 - root_mean_squared_error: 0.3282
# Epoch 105/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0981 - r2_score: 0.9521 - root_mean_squared_error: 0.3131
# Epoch 106/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1185 - r2_score: 0.9455 - root_mean_squared_error: 0.3429
# Epoch 107/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1111 - r2_score: 0.9478 - root_mean_squared_error: 0.3330
# Epoch 108/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1036 - r2_score: 0.9491 - root_mean_squared_error: 0.3218
# Epoch 109/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0886 - r2_score: 0.9574 - root_mean_squared_error: 0.2968
# Epoch 110/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0974 - r2_score: 0.9435 - root_mean_squared_error: 0.3116
# Epoch 111/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0976 - r2_score: 0.9525 - root_mean_squared_error: 0.3119
# Epoch 112/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1024 - r2_score: 0.9562 - root_mean_squared_error: 0.3200
# Epoch 113/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0855 - r2_score: 0.9621 - root_mean_squared_error: 0.2913
# Epoch 114/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0923 - r2_score: 0.9547 - root_mean_squared_error: 0.3035
# Epoch 115/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0832 - r2_score: 0.9599 - root_mean_squared_error: 0.2868
# Epoch 116/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0989 - r2_score: 0.9556 - root_mean_squared_error: 0.3141
# Epoch 117/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1027 - r2_score: 0.9511 - root_mean_squared_error: 0.3204
# Epoch 118/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0998 - r2_score: 0.9525 - root_mean_squared_error: 0.3155
# Epoch 119/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1048 - r2_score: 0.9453 - root_mean_squared_error: 0.3229
# Epoch 120/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0895 - r2_score: 0.9600 - root_mean_squared_error: 0.2985
# Epoch 121/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0932 - r2_score: 0.9559 - root_mean_squared_error: 0.3053
# Epoch 122/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1016 - r2_score: 0.9519 - root_mean_squared_error: 0.3186
# Epoch 123/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1047 - r2_score: 0.9514 - root_mean_squared_error: 0.3230
# Epoch 124/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1021 - r2_score: 0.9494 - root_mean_squared_error: 0.3193
# Epoch 125/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0889 - r2_score: 0.9573 - root_mean_squared_error: 0.2979
# Epoch 126/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0968 - r2_score: 0.9544 - root_mean_squared_error: 0.3111
# Epoch 127/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1057 - r2_score: 0.9474 - root_mean_squared_error: 0.3243
# Epoch 128/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1008 - r2_score: 0.9547 - root_mean_squared_error: 0.3173
# Epoch 129/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0983 - r2_score: 0.9567 - root_mean_squared_error: 0.3128
# Epoch 130/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0988 - r2_score: 0.9523 - root_mean_squared_error: 0.3130
# Epoch 131/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0826 - r2_score: 0.9607 - root_mean_squared_error: 0.2863
# Epoch 132/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1134 - r2_score: 0.9484 - root_mean_squared_error: 0.3358
# Epoch 133/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0819 - r2_score: 0.9622 - root_mean_squared_error: 0.2857
# Epoch 134/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0857 - r2_score: 0.9611 - root_mean_squared_error: 0.2923
# Epoch 135/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1023 - r2_score: 0.9531 - root_mean_squared_error: 0.3195
# Epoch 136/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0977 - r2_score: 0.9571 - root_mean_squared_error: 0.3124
# Epoch 137/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0985 - r2_score: 0.9532 - root_mean_squared_error: 0.3138
# Epoch 138/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0847 - r2_score: 0.9634 - root_mean_squared_error: 0.2908
# Epoch 139/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0808 - r2_score: 0.9635 - root_mean_squared_error: 0.2819
# Epoch 140/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0852 - r2_score: 0.9589 - root_mean_squared_error: 0.2915
# Epoch 141/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0905 - r2_score: 0.9598 - root_mean_squared_error: 0.3006
# Epoch 142/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0895 - r2_score: 0.9583 - root_mean_squared_error: 0.2987
# Epoch 143/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0956 - r2_score: 0.9523 - root_mean_squared_error: 0.3091
# Epoch 144/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0943 - r2_score: 0.9524 - root_mean_squared_error: 0.3064
# Epoch 145/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0817 - r2_score: 0.9523 - root_mean_squared_error: 0.2854
# Epoch 146/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1042 - r2_score: 0.9542 - root_mean_squared_error: 0.3224
# Epoch 147/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0829 - r2_score: 0.9629 - root_mean_squared_error: 0.2876
# Epoch 148/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0758 - r2_score: 0.9645 - root_mean_squared_error: 0.2739
# Epoch 149/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1009 - r2_score: 0.9550 - root_mean_squared_error: 0.3172
# Epoch 150/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0857 - r2_score: 0.9579 - root_mean_squared_error: 0.2925

# %% [markdown]
# ## Model Evaluation

# %%
y_pred = model.predict(X_test_scaled)
Y = [None]*len(X_train) + y_pred.tolist()
plt.subplots(2,1, figsize= (10,10))
plt.subplot(2,1,1)
plt.title('Neural Network')
plt.ylabel('Price')
plt.xlabel('Year')
plt.plot(X_train_graph, y_train, label= 'Train', color= 'blue', alpha= .7)
plt.plot(X_test_graph, y_test, label= 'Test', color= 'red', alpha= .7)
plt.plot(X_test_graph, y_pred, label= 'Predicted', color= 'green', alpha= .7)
plt.legend()
plt.grid()
plt.tight_layout()

plt.subplot(2,1,2)
plt.title('Neural Network')
plt.ylabel('Price')
plt.xlabel('Year')
plt.plot(X_test_graph, y_test, label= 'Test', color= 'red', alpha= .7)
plt.plot(X_test_graph, y_pred, label= 'Predicted', color= 'green', alpha= .7)
plt.legend()
plt.grid()
plt.tight_layout()

plt.show()
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step

# %% [markdown]
# The neural network model is extremely good at capturing the patterns in the data set. The test vs predicted subplot shows this clearly because the predicted graph follows the same trend the actual data does even in the years after 2022 where price volatility is at its highest. Let us see the metrics to see how well it actually performed.

# %%
y_pred = model.predict(X_test_scaled)
nn_pred = y_pred
print(f'Root Mean Squared Error: {np.sqrt(mean_squared_error(y_test, y_pred))}')
print(f'R^{2} Score: {r2_score(y_test, y_pred)}')
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Root Mean Squared Error: 0.6269811256286603
# R^2 Score: 0.8413280022497458

# %% [markdown]
# As expected from the graph, the evaluation metrics are good. With an rmse of .62 and R2 score of .84, it means that the model captures the variance of the target variable extremely well, and that on average, the difference between the predicted and expected data points from the test set only differ 52 cents. In all scoring metrics the neural network far exceeds the previous sklearn regression models, and is the best regression based model for forecasting.

# %%
history_df = pd.DataFrame(history.history)

plt.subplots(2,1, figsize= (9,11))
plt.subplot(2,1,1)
plt.title('Scoring over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Score')
plt.plot(history_df['loss'], label= 'Training Loss')
plt.plot(history_df['r2_score'], label= 'Training R^2')
plt.legend()
plt.grid()

plt.subplot(2,1,2)
plt.title('Scoring over Epochs (first 10 epochs)')
plt.xlabel('Epochs')
plt.ylabel('Score')
plt.plot(history_df['loss'][:10], label= 'Training Loss')
plt.plot(history_df['r2_score'][:10], label= 'Training R^2')
plt.legend()
plt.grid()

plt.show()

# %% [markdown]
# Here we look at how the loss function and R2 score change over each epoch and this shows that the R2 score and loss function intersect at the first epoch and then after that they go on they do not intersect again, as each metric respectively converges to .62 and .84 after this intersection till the 150th epoch.

# %% [markdown]
# # Forecasting Methods

# %% [markdown]
# ## Prophet Model

# %% [markdown]
# The first forecasting model will be the FBProphet model

# %%
# !pip install prophet
# Out:
# Requirement already satisfied: prophet in /usr/local/lib/python3.10/dist-packages (1.1.6)
# Requirement already satisfied: cmdstanpy>=1.0.4 in /usr/local/lib/python3.10/dist-packages (from prophet) (1.2.5)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.10/dist-packages (from prophet) (1.26.4)
# Requirement already satisfied: matplotlib>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from prophet) (3.10.0)
# Requirement already satisfied: pandas>=1.0.4 in /usr/local/lib/python3.10/dist-packages (from prophet) (2.2.2)
# Requirement already satisfied: holidays<1,>=0.25 in /usr/local/lib/python3.10/dist-packages (from prophet) (0.63)
# Requirement already satisfied: tqdm>=4.36.1 in /usr/local/lib/python3.10/dist-packages (from prophet) (4.67.1)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from prophet) (6.5.2)
# Requirement already satisfied: stanio<2.0.0,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from cmdstanpy>=1.0.4->prophet) (0.5.1)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from holidays<1,>=0.25->prophet) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->prophet) (3.2.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.4->prophet) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.4->prophet) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil->holidays<1,>=0.25->prophet) (1.17.0)

# %% [markdown]
# ### Data preparation

# %%
simple = df[['Date', 'Price']].copy()
simple.set_index('Date', inplace= True)
simple.index.name = 'ds'
simple.columns = ['y']
simple.reset_index(inplace= True)
simple.head()
# Out:
#           ds     y
# 0 1994-05-01  5.43
# 1 1994-06-01  5.46
# 2 1994-07-01  5.24
# 3 1994-08-01  5.02
# 4 1994-09-01  5.28

# %% [markdown]
# In many time series forecasting models, feature engineering is not needed as it is for regression based techniques, as the model is expected to handle this. The prophet model requires a column in date time format named ds and a target column named y. The above cell correctly formats the dataframe, simple, so we can feed it into Prophet.

# %% [markdown]
# ### Model Training

# %%
from prophet import Prophet

simple_train = simple[:split_point]
simple_test = simple[split_point:]

model = Prophet()
model.fit(simple_train)
# Out:
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbdnukjk7/qmbkrvhu.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbdnukjk7/yqxo0kzx.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=43552', 'data', 'file=/tmp/tmpbdnukjk7/qmbkrvhu.json', 'init=/tmp/tmpbdnukjk7/yqxo0kzx.json', 'output', 'file=/tmp/tmpbdnukjk7/prophet_modelsy8fr6lc/prophet_model-20250110010414.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 01:04:14 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:04:14 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %% [markdown]
# Similar to our regression based techniques, we need to split the data into test and training sets, and we will use the same structure as we did in our regression based techniques with the 80/20 split. Then we are able to feed our training data into the model

# %%
simple_forecast = model.predict(simple_test)
simple_forecast.head()
# Out:
#           ds     trend  yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 0 2018-02-01  7.258201    6.448150    8.200467     7.258201     7.258201
# 1 2018-03-01  7.278174    6.598273    8.346519     7.278174     7.278174
# 2 2018-04-01  7.300288    6.751794    8.559126     7.299775     7.300392
# 3 2018-05-01  7.321688    6.834970    8.589081     7.320307     7.322188
# 4 2018-06-01  7.343802    6.701920    8.453608     7.341624     7.345318
#
#    additive_terms  additive_terms_lower  additive_terms_upper    yearly  \
# 0        0.064415              0.064415              0.064415  0.064415
# 1        0.163049              0.163049              0.163049  0.163049
# 2        0.339710              0.339710              0.339710  0.339710
# 3        0.390635              0.390635              0.390635  0.390635
# 4        0.218370              0.218370              0.218370  0.218370
#
#    yearly_lower  yearly_upper  multiplicative_terms  \
# 0      0.064415      0.064415                   0.0
# 1      0.163049      0.163049                   0.0
# 2      0.339710      0.339710                   0.0
# 3      0.390635      0.390635                   0.0
# 4      0.218370      0.218370                   0.0
#
#    multiplicative_terms_lower  multiplicative_terms_upper      yhat
# 0                         0.0                         0.0  7.322616
# 1                         0.0                         0.0  7.441223
# 2                         0.0                         0.0  7.639998
# 3                         0.0                         0.0  7.712323
# 4                         0.0                         0.0  7.562172

# %% [markdown]
# ### Model Evaluation

# %%
fig, ax = plt.subplots(figsize= (8,6))
ax.set_title('Prophet Forecasting')
ax.set_xlabel('Year')
ax.set_ylabel('Price')
model.plot(simple_forecast, ax= ax)
ax.legend()
plt.show()

# %%
model.plot_components(simple_forecast)
plt.show()

# %% [markdown]
# The first plot shows the trend of the models predictions over the testing dates. The second plot shows the seasonality of price throughout the year, so the model predicts a linear and seasonal trend.

# %%
fig, ax = plt.subplots(figsize= (8,6))
plt.scatter(simple_train['ds'], simple_train['y'], label= 'Train Data', color= 'blue', alpha= .5)
plt.scatter(simple_test['ds'], simple_test['y'], label= 'Test Data', color= 'red', alpha= .5)
model.plot(simple_forecast, ax=ax)
ax.set_title('Prophet Forecasting')
ax.set_xlabel('Year')
ax.set_ylabel('Price')
plt.legend()
plt.show()

# %% [markdown]
# Here we are able to see how the model predicts compared with the observed data as well as the testing data. When observing the training data and the model forecast, this trend seems to make sense as it continues a positive linear trend with seasonality as previously seen, however, it does not appear to test well with the unseen testing data since the testing data is extremely volatile.

# %%
fig, ax = plt.subplots(figsize= (8,6))
ax.scatter(simple_test['ds'], simple_test['y'], label= 'Test Data', color= 'red', alpha= .5)
model.plot(simple_forecast, ax=ax)
ax.set_xbound(lower= simple_test['ds'].min(), upper= simple_test['ds'].max())
ax.set_title('Prophet Forecasting (Zoomed)')
ax.set_xlabel('Year')
ax.set_ylabel('Price')
plt.legend()
plt.show()

# %% [markdown]
# In a closer zoom in, its more clear that the prophet model does not forecast the test set accurately. It shows more of a linear trend than adapting to the sharp seasonal patterns in the test set.

# %%
print('Prophet:')
print('RMSE: ', np.sqrt(mean_squared_error(simple_test['y'], simple_forecast['yhat'])))
print('R^2: ', r2_score(simple_test['y'], simple_forecast['yhat']))
# Out:
# Prophet:
# RMSE:  1.35627007127694
# R^2:  0.2157330131056705

# %% [markdown]
# As expected, the evaluation metrics show that the prophet model does not perform that well. It performs better than the sklearn regression models but is far worse compared to the neural network model.

# %% [markdown]
# ## LSTM Forecasting

# %% [markdown]
# ## Data Preparation

# %%
table =df.copy()
table.set_index('Date', inplace= True)
table.head()
# Out:
#             Change in decimal  Price  Year  Month  Quarter     Month_sin  \
# Date
# 1994-05-01                NaN   5.43  1994      5        2  5.000000e-01
# 1994-06-01             0.0055   5.46  1994      6        2  1.224647e-16
# 1994-07-01            -0.0403   5.24  1994      7        3 -5.000000e-01
# 1994-08-01            -0.0420   5.02  1994      8        3 -8.660254e-01
# 1994-09-01             0.0518   5.28  1994      9        3 -1.000000e+00
#
#                Month_cos  lag_1  lag_2  lag_3  rolling_avg_3
# Date
# 1994-05-01 -8.660254e-01    NaN    NaN    NaN            NaN
# 1994-06-01 -1.000000e+00   5.43    NaN    NaN            NaN
# 1994-07-01 -8.660254e-01   5.46   5.43    NaN       5.376667
# 1994-08-01 -5.000000e-01   5.24   5.46   5.43       5.240000
# 1994-09-01 -1.836970e-16   5.02   5.24   5.46       5.180000

# %%
table = df.copy()
table.set_index('Date', inplace= True)
table = table[['lag_1', 'lag_2', 'lag_3', 'rolling_avg_3', 'Price']].dropna()
table.head()
# Out:
#             lag_1  lag_2  lag_3  rolling_avg_3  Price
# Date
# 1994-08-01   5.24   5.46   5.43       5.240000   5.02
# 1994-09-01   5.02   5.24   5.46       5.180000   5.28
# 1994-10-01   5.28   5.02   5.24       5.216667   5.35
# 1994-11-01   5.35   5.28   5.02       5.160000   4.85
# 1994-12-01   4.85   5.35   5.28       5.030000   4.89

# %% [markdown]
# ### Model Training

# %%
scaler = MinMaxScaler()
table_scaled = pd.DataFrame(scaler.fit_transform(table), columns= table.columns, index= table.index)
table_scaled.head()
# Out:
#                lag_1     lag_2     lag_3  rolling_avg_3     Price
# Date
# 1994-08-01  0.320904  0.345763  0.342373       0.328751  0.296045
# 1994-09-01  0.296045  0.320904  0.345763       0.321472  0.325424
# 1994-10-01  0.325424  0.296045  0.320904       0.325920  0.333333
# 1994-11-01  0.333333  0.325424  0.296045       0.319046  0.276836
# 1994-12-01  0.276836  0.333333  0.325424       0.303275  0.281356

# %%
X = table_scaled.drop('Price', axis= 1).values
y = table_scaled['Price'].values


X = X.reshape((X.shape[0], 1, X.shape[1]))

# %%
split_point = int(len(X)*.8)

X_train = X[:split_point]
X_test = X[split_point+3:] # for lag features
y_train = y[:split_point]
y_test = y[split_point+3:] # for lag features

# %%
from tensorflow.keras.layers import LSTM

model = keras.Sequential(
    [
        keras.layers.LSTM(50, activation= 'relu',input_shape= (X_train.shape[1], X_train.shape[2])),
        keras.layers.Dense(1)
    ]
)

# %%
model.compile(optimizer= 'adam', loss= 'mse', metrics= [metrics.RootMeanSquaredError(), metrics.R2Score()])

# %%
history = model.fit(X_train, y_train, epochs=75, batch_size=32, verbose=1)
# Out:
# Epoch 1/75
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0777 - r2_score: -1.8928 - root_mean_squared_error: 0.2787
# Epoch 2/75
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0646 - r2_score: -1.5115 - root_mean_squared_error: 0.2541
# Epoch 3/75
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0560 - r2_score: -0.9326 - root_mean_squared_error: 0.2365
# Epoch 4/75
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0443 - r2_score: -0.6728 - root_mean_squared_error: 0.2103
# Epoch 5/75
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0365 - r2_score: -0.2743 - root_mean_squared_error: 0.1902
# Epoch 6/75
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0193 - r2_score: 0.2382 - root_mean_squared_error: 0.1385
# Epoch 7/75
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0142 - r2_score: 0.4734 - root_mean_squared_error: 0.1191
# Epoch 8/75
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0102 - r2_score: 0.6211 - root_mean_squared_error: 0.1010
# Epoch 9/75
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0069 - r2_score: 0.7216 - root_mean_squared_error: 0.0831
# Epoch 10/75
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0062 - r2_score: 0.7843 - root_mean_squared_error: 0.0785
# Epoch 11/75
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0056 - r2_score: 0.8032 - root_mean_squared_error: 0.0745
# Epoch 12/75
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0051 - r2_score: 0.8055 - root_mean_squared_error: 0.0715
# Epoch 13/75
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0049 - r2_score: 0.8272 - root_mean_squared_error: 0.0697
# Epoch 14/75
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0044 - r2_score: 0.8333 - root_mean_squared_error: 0.0666
# Epoch 15/75
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0042 - r2_score: 0.8420 - root_mean_squared_error: 0.0645
# Epoch 16/75
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0036 - r2_score: 0.8535 - root_mean_squared_error: 0.0601
# Epoch 17/75
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0035 - r2_score: 0.8554 - root_mean_squared_error: 0.0596
# Epoch 18/75
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0036 - r2_score: 0.8769 - root_mean_squared_error: 0.0601
# Epoch 19/75
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0034 - r2_score: 0.8838 - root_mean_squared_error: 0.0580
# Epoch 20/75
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0030 - r2_score: 0.8852 - root_mean_squared_error: 0.0550
# Epoch 21/75
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0030 - r2_score: 0.8872 - root_mean_squared_error: 0.0549
# Epoch 22/75
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0025 - r2_score: 0.9051 - root_mean_squared_error: 0.0496
# Epoch 23/75
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0029 - r2_score: 0.8962 - root_mean_squared_error: 0.0535
# Epoch 24/75
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0027 - r2_score: 0.9054 - root_mean_squared_error: 0.0519
# Epoch 25/75
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0027 - r2_score: 0.9088 - root_mean_squared_error: 0.0518
# Epoch 26/75
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0026 - r2_score: 0.9110 - root_mean_squared_error: 0.0505
# Epoch 27/75
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0022 - r2_score: 0.9205 - root_mean_squared_error: 0.0466
# Epoch 28/75
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0021 - r2_score: 0.9113 - root_mean_squared_error: 0.0460
# Epoch 29/75
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0024 - r2_score: 0.9112 - root_mean_squared_error: 0.0488
# Epoch 30/75
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0023 - r2_score: 0.9175 - root_mean_squared_error: 0.0479
# Epoch 31/75
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0025 - r2_score: 0.9149 - root_mean_squared_error: 0.0495
# Epoch 32/75
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0025 - r2_score: 0.9108 - root_mean_squared_error: 0.0502
# Epoch 33/75
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0022 - r2_score: 0.9203 - root_mean_squared_error: 0.0467
# Epoch 34/75
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0024 - r2_score: 0.9134 - root_mean_squared_error: 0.0486
# Epoch 35/75
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0023 - r2_score: 0.9149 - root_mean_squared_error: 0.0480
# Epoch 36/75
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0025 - r2_score: 0.9123 - root_mean_squared_error: 0.0502
# Epoch 37/75
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0022 - r2_score: 0.9142 - root_mean_squared_error: 0.0466
# Epoch 38/75
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0022 - r2_score: 0.9207 - root_mean_squared_error: 0.0472
# Epoch 39/75
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0023 - r2_score: 0.9144 - root_mean_squared_error: 0.0476
# Epoch 40/75
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0024 - r2_score: 0.9180 - root_mean_squared_error: 0.0488
# Epoch 41/75
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0020 - r2_score: 0.9232 - root_mean_squared_error: 0.0446
# Epoch 42/75
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0020 - r2_score: 0.9279 - root_mean_squared_error: 0.0452
# Epoch 43/75
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0018 - r2_score: 0.9330 - root_mean_squared_error: 0.0429
# Epoch 44/75
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0021 - r2_score: 0.9185 - root_mean_squared_error: 0.0454
# Epoch 45/75
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0020 - r2_score: 0.9236 - root_mean_squared_error: 0.0450
# Epoch 46/75
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0025 - r2_score: 0.9056 - root_mean_squared_error: 0.0501
# Epoch 47/75
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0015 - r2_score: 0.9467 - root_mean_squared_error: 0.0381
# Epoch 48/75
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0019 - r2_score: 0.9265 - root_mean_squared_error: 0.0441
# Epoch 49/75
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0021 - r2_score: 0.9209 - root_mean_squared_error: 0.0457
# Epoch 50/75
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0018 - r2_score: 0.9268 - root_mean_squared_error: 0.0428
# Epoch 51/75
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0018 - r2_score: 0.9330 - root_mean_squared_error: 0.0426
# Epoch 52/75
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0020 - r2_score: 0.9271 - root_mean_squared_error: 0.0451
# Epoch 53/75
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0019 - r2_score: 0.9237 - root_mean_squared_error: 0.0432
# Epoch 54/75
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0021 - r2_score: 0.9174 - root_mean_squared_error: 0.0462
# Epoch 55/75
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0018 - r2_score: 0.9362 - root_mean_squared_error: 0.0418
# Epoch 56/75
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0019 - r2_score: 0.9323 - root_mean_squared_error: 0.0431
# Epoch 57/75
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0022 - r2_score: 0.9207 - root_mean_squared_error: 0.0464
# Epoch 58/75
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0018 - r2_score: 0.9374 - root_mean_squared_error: 0.0421
# Epoch 59/75
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0020 - r2_score: 0.9239 - root_mean_squared_error: 0.0450
# Epoch 60/75
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0018 - r2_score: 0.9319 - root_mean_squared_error: 0.0428
# Epoch 61/75
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0019 - r2_score: 0.9297 - root_mean_squared_error: 0.0432
# Epoch 62/75
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0018 - r2_score: 0.9423 - root_mean_squared_error: 0.0420
# Epoch 63/75
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0016 - r2_score: 0.9354 - root_mean_squared_error: 0.0395
# Epoch 64/75
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0020 - r2_score: 0.9324 - root_mean_squared_error: 0.0443
# Epoch 65/75
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0015 - r2_score: 0.9318 - root_mean_squared_error: 0.0382
# Epoch 66/75
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0019 - r2_score: 0.9399 - root_mean_squared_error: 0.0433
# Epoch 67/75
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0017 - r2_score: 0.9408 - root_mean_squared_error: 0.0407
# Epoch 68/75
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0018 - r2_score: 0.9393 - root_mean_squared_error: 0.0420
# Epoch 69/75
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0017 - r2_score: 0.9407 - root_mean_squared_error: 0.0406
# Epoch 70/75
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0015 - r2_score: 0.9392 - root_mean_squared_error: 0.0391
# Epoch 71/75
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0017 - r2_score: 0.9333 - root_mean_squared_error: 0.0413
# Epoch 72/75
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0016 - r2_score: 0.9448 - root_mean_squared_error: 0.0401
# Epoch 73/75
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0015 - r2_score: 0.9493 - root_mean_squared_error: 0.0382
# Epoch 74/75
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0017 - r2_score: 0.9336 - root_mean_squared_error: 0.0415
# Epoch 75/75
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0014 - r2_score: 0.9505 - root_mean_squared_error: 0.0373

# %% [markdown]
# ### Model Evaluation

# %%
fig, ax= plt.subplots(1,2, figsize= (15,8))

ax[0].plot(X_train_graph, y_train,label= 'Train Set')
ax[0].plot(X_test_graph, y_test,label= 'Test Set')
ax[0].plot(X_test_graph, y_pred,label= 'Predicted')
ax[0].grid()
ax[0].legend()
ax[0].set_title('LSTM Forecasting')
ax[0].set_xlabel('Year')
ax[0].set_ylabel('Price')

ax[1].plot(X_test_graph, y_test,label= 'Test Set', color= 'orange')
ax[1].plot(X_test_graph, y_pred,label= 'Predicted', color= 'green')
ax[1].grid()
ax[1].legend()
ax[1].set_title('LSTM Forecasting (Zoomed)')
ax[1].set_xlabel('Year')
ax[1].set_ylabel('Price')


plt.show()

# %% [markdown]
# The model performs extremely well on the unseen testing data, it perfectly captures the trends in the testing data, even in the most volatile price years (2022-2024), this will be the best overall model when it comes to forecasting.

# %%
y_pred = model.predict(X_test)
print('LSTM Forecasting: ')
print(f'Root Mean Squared Error: {np.sqrt(mean_squared_error(y_test, y_pred))}')
print(f'R^{2} Score: {r2_score(y_test, y_pred)}')
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# LSTM Forecasting:
# Root Mean Squared Error: 0.09436444836728014
# R^2 Score: 0.718489429033426

# %% [markdown]
# When it comes to predicting values, this model is the best, with an rmse of .09, the average prediction was only 9 cents off the actual value which is extremely good. The R2 score is .71, which still encapsulates the variance of the price greatly.

# %% [markdown]
# # Conclusions

# %%
fig, ax = plt.subplots(figsize= (10,6))
ax.set_title('Comparison of Forecasting Models')
ax.set_xlabel('Year')
ax.set_ylabel('Price')
ax.plot(X_test_graph, y_test, label= 'Actual', color= 'blue')
ax.plot(X_test_graph, simple_forecast['yhat'][6:], label= 'Prophet', color= 'green', alpha= .8)
ax.plot(X_test_graph, y_pred, label= 'LSTM', color= 'red', alpha= .8)
ax.plot(X_test_graph, predictions['Gradient Boosting Regression'], label= 'Gradient Boosting', color= 'orange', alpha= .8)
ax.plot(X_test_graph, nn_pred, label= 'Neural Network Regression', color= 'magenta', alpha= .8)
ax.legend()
ax.grid()
plt.show()

# %% [markdown]
# Here is a final plot with the best performing models from each section excluding linear regression. It appears that LSTM and neural network regression models perform essentially the same since they overlap each other. The worst performing model from the graph seems to be the prophet model, while the best model are either of the neural network based models, but due to the lower rmse, the LSTM is the overall best model when it comes to salmon price forecasting. Both techniques for time series forecasting provided their benefits and difficulties, however, to choose an overall winner it would have to be neural network based models as they far exceeded the other type of regression and time series based models.
